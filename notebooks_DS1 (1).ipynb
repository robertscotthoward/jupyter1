# %% [markdown]
# for i in range(100):
#     print(i, i*i)

# %% [markdown]
# # Example
#
# I'm giving an example in markdown.
#
# $ x = {-b \pm \sqrt{b^2-4ac} \over 2a} $
#
#
# $\displaystyle \int_{-\infty }^{\infty}f(x)dx$
#
# $ y = m x + b$

# %%
2 ** 100
# Out:
# 1267650600228229401496703205376
